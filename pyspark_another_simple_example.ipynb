# %% [markdown]
# <a href="https://colab.research.google.com/github/trefftzc/cis677/blob/main/pyspark_another_simple_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Another example of PySpark
#
# We will revisit the polynomial that you plotted for project 3 (Fall 2025).
#
# pyspark is already available in COLAB.

# %%
import pyspark

pyspark.__version__
# Out:
# '3.5.1'

# %%
import os
#import findspark

# Ensure any previously misconfigured SPARK_HOME is cleared
#if "SPARK_HOME" in os.environ:
#    del os.environ["SPARK_HOME"]

#findspark.init()
from pyspark.sql import  SparkSession
spark = SparkSession.builder.appName("Example").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# /tmp/ipython-input-4088054171.py in <cell line: 0>()
#       8 #findspark.init()
#       9 from pyspark.sql import  SparkSession
# ---> 10 spark = SparkSession.builder.appName("Example").getOrCreate()
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in getOrCreate(self)
#     495                         sparkConf.set(key, value)
#     496                     # This SparkContext may be an existing one.
# --> 497                     sc = SparkContext.getOrCreate(sparkConf)
#     498                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499                     # by all sessions.
#
# /usr/local/lib/python3.12/dist-packages/pyspark/context.py in getOrCreate(cls, conf)
#     513         with SparkContext._lock:
# ...

# %%
import numpy as np
x = np.linspace(-4,4,1000)
#print(x)

# %%
x_rdd = spark.sparkContext.parallelize(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1785469370.py in <cell line: 0>()
# ----> 1 x_rdd = spark.sparkContext.parallelize(x)
#
# NameError: name 'spark' is not defined

# %%
print(x_rdd)

# %% [markdown]
# The definition of the function

# %%
def f(x):
    return x**4 - 10*x**2 + 9

# %%
print (f(-4.0),f(-2.2),f(-1.0),f(0.0),f(1.0),f(2.2),f(4.0))

# %%
result_rdd = x_rdd.map(f)

# %%
print(result_rdd)

# %%
max_value = result_rdd.reduce(max)
min_value = result_rdd.reduce(min)
print("The min value is: ",min_value)
print("The max value is: ",max_value)
